# %% [markdown]
# ### lambda function
#
#     A lambda function is a small anonymous function
#     A lambda function can take any number of arguments, but can only have one expression.
#
#     variable = lambda arguments : expression

# %%
x = lambda a : a + 10
x(5)
# Out:
# 15

# %%
x = lambda a, b : a * b
x(5, 6)
# Out:
# 30

# %%
x = lambda a, b, c : a + b + c
x(5, 6, 2)
# Out:
# 13

# %%
def myfunc(n):
    return lambda a : a * n

# %%
mydoubler = myfunc(2)
print(mydoubler(11))
# Out:
# 22

# %%
myfunc(5)(11)
# Out:
# 55

# %%
rate = lambda T: 200*exp(-T) if T>200 else 400*exp(-T)
rate(200)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-14-8a1821e96a87> in <module>
#       1 rate = lambda T: 200*exp(-T) if T>200 else 400*exp(-T)
# ----> 2 rate(200)
#
# <ipython-input-14-8a1821e96a87> in <lambda>(T)
# ----> 1 rate = lambda T: 200*exp(-T) if T>200 else 400*exp(-T)
#       2 rate(200)
#
# NameError: name 'exp' is not defined

# %%
rate = lambda T: T if (T>200 or T < 500)
# Out:
#   File "<ipython-input-11-9b3cf13da4c7>", line 1
#     rate = lambda T: T if (T>200 or T < 500)
#                                             ^
# SyntaxError: invalid syntax

# %% [markdown]
# ### yield Keyword
#     yield is a keyword in Python that is used to return from a function without destroying the states of its local variable and when the function is called, the execution starts from the last yield statement. Any function that contains a yield keyword is termed as generator.

# %%
def print_even(test_list) : 
    for i in test_list: 
        if i % 2 == 0: 
            yield i 

test_list = [1, 4, 5, 6, 7]  
for j in print_even(test_list): 
    print (j, end = " ")
# Out:
# 4 6

# %%
def reverse(data):
    for index in range(len(data)-1, -1, -1):
        yield data[index]
        
for char in reverse('golf'):
     print(char)
# Out:
# f
# l
# o
# g

# %% [markdown]
# ### Filter Function
#
#     Filter takes a function and a collection. It returns a collection of every item
#     for which the function returned True.

# %%
arr=[1,2,3,4,5,6]
s=lambda x:x>4
s
# Out:
# <function __main__.<lambda>(x)>

# %%
a=filter(s,arr) # object address
a

# %%
c=list(a)
print(c)   #[5,6]
# Out:
# [5, 6]

# %% [markdown]
# ### Reduce Function
#
#     Reduce takes a function and a collection of items. It returns a value that is created by combining the items.
#     This is a simple reduce. It returns the sum of all the items in the collection.

# %%
from functools import reduce
data=[0, 1, 2, 3, 4]
# sum(data)
# Out:
# 10

# %%
fun=lambda a, x: a + x
total = reduce(fun, data)
print(total)                          #10
# Out:
# 10
